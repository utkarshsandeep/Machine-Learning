# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import warnings
from collections import Counter
style.use('fivethirtyeight')
import pandas as pd

# %%
def handle_non_numerical_data(df):
    columns=df.columns.values
    #print(columns)
    for column in columns:
        text_digit_vals={}
        def convert_to_int(val):
            return text_digit_vals[val]
        if df[column].dtype!=np.int64 and df[column].dtype!=np.float64:
            column_contents=df[column].values.tolist()
            unique_elements=set(column_contents)
            x=0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    text_digit_vals[unique]=x
                    #print(unique,x)
                    x+=1
            df[column]=list(map(convert_to_int,df[columns]))
    return df

# %%
colors=['green','red']

# %%
df=pd.read_csv('Hoteldata.csv')
print(df)
df=df.drop(['CustomerID'],1)
df=handle_non_numerical_data(df)
print(df)
Booked=df['Booked']
# Out:
#       CustomerID  DaysBooking  HotelStar  NoOfPerson  Season Breakfast WiFi  \
# 0              1            2          3           1     LOW        NO  YES
# 1              2            3          5           4    HIGH       YES   NO
# 2              3            4          2           2  MEDIUM        NO  YES
# 3              4            2          3           2    HIGH       YES   NO
# 4              5            2          5           2  MEDIUM       YES  YES
# 5              6            4          3           4     LOW       YES  YES
# 6              7            3          3           1     LOW       YES  YES
# 7              8            4          5           2  MEDIUM        NO  YES
# 8              9            2          2           2    HIGH        NO  YES
# 9             10            4          2           2    HIGH       YES  YES
# 10            11            3          2           3     LOW       YES  YES
# 11            12            3          3           1     LOW        NO  YES
# 12            13            3          5           2  MEDIUM        NO  YES
# 13            14            2          3           2    HIGH        NO  YES
# 14            15            3          3           1  MEDIUM       YES  YES
# 15            16            3          5           2    HIGH       YES  YES
# 16            17            1          2           1     LOW        NO  YES
# 17            18            3          3           2  MEDIUM       YES   NO
# 18            19            4          3           1     LOW       YES  YES
# 19            20            2          4           2  MEDIUM       YES  YES
# 20            21            5          3           4  MEDIUM       YES   NO
# 21            22            2          3           1     LOW        NO   NO
# 22            23            3          5           2    HIGH       YES  YES
# 23            24            3          4           4  MEDIUM       YES  YES
# 24            25            4          2           2     LOW        NO  YES
# 25            26            2          5           1  MEDIUM        NO  YES
# 26            27            3          3           2    HIGH       YES   NO
# 27            28            3          4           1  MEDIUM        NO   NO
# 28            29            2          5           1     LOW       YES  YES
# 29            30            3          3           2    HIGH       YES   NO
# ...          ...          ...        ...         ...     ...       ...  ...
# 1182        1183            3          4           4    HIGH        NO   NO
# 1183        1184            3          2           4  MEDIUM       YES   NO
# 1184        1185            3          3           4    HIGH        NO  YES
# 1185        1186            2          4           3     LOW       YES  YES
# 1186        1187            5          3           4  MEDIUM       YES  YES
# 1187        1188            3          4           4    HIGH        NO  YES
# 1188        1189            2          5           3  MEDIUM       YES  YES
# 1189        1190            1          3           2     LOW        NO  YES
# 1190        1191            3          5           2  MEDIUM        NO  YES
# 1191        1192            4          4           3     LOW       YES  YES
# 1192        1193            5          4           4     LOW        NO   NO
# 1193        1194            3          3           2     LOW       YES   NO
# 1194        1195            4          5           1  MEDIUM        NO  YES
# 1195        1196            5          4           2    HIGH       YES  YES
# 1196        1197            4          3           3  MEDIUM        NO  YES
# 1197        1198            3          4           2  MEDIUM       YES  YES
# 1198        1199            2          3           1     LOW       YES  YES
# 1199        1200            3          3           4    HIGH       YES  YES
# 1200        1201            4          3           2  MEDIUM       YES  YES
# 1201        1202            5          3           4    HIGH       YES  YES
# 1202        1203            3          2           1     LOW        NO  YES
# 1203        1204            5          4           2    HIGH       YES  YES
# 1204        1205            4          5           2  MEDIUM       YES   NO
# 1205        1206            1          3           2  MEDIUM       YES  YES
# 1206        1207            2          4           1     LOW        NO  YES
# 1207        1208            4          3           2    HIGH       YES  YES
# 1208        1209            3          3           1  MEDIUM        NO  YES
# 1209        1210            3          4           2     LOW        NO  YES
# 1210        1211            2          4           4    HIGH       YES  YES
# 1211        1212            4          5           2     LOW       YES  YES
#
#      AC/NON AC  Price  Age Booked
# 0           AC   2000   20    YES
# 1           AC   3000   40     NO
# 2       NON AC   4000   30    YES
# 3           AC   3000   20     NO
# 4           AC   4000   20    YES
# 5           AC   4000   40    YES
# 6       NON AC   2000   20    YES
# 7           AC   3000   20    YES
# 8           AC   5000   30     NO
# 9       NON AC   5000   20     NO
# 10          AC   3000   30    YES
# 11          AC   4000   40    YES
# 12          AC   4000   20    YES
# 13          AC   3000   30     NO
# 14          AC   2000   50    YES
# 15          AC   4000   40    YES
# 16          AC   3000   20     NO
# 17          AC   3000   30     NO
# 18          AC   3000   20    YES
# 19          AC   4000   30    YES
# 20          AC   4000   40     NO
# 21      NON AC   2000   20    YES
# 22          AC   6000   30     NO
# 23          AC   4000   40    YES
# 24          AC   2000   20    YES
# 25          AC   4000   30    YES
# 26          AC   5000   50     NO
# 27          AC   2000   30     NO
# 28          AC   4000   50    YES
# 29      NON AC   5000   60    YES
# ...        ...    ...  ...    ...
# 1182        AC   5000   30    YES
# 1183    NON AC   4000   40     NO
# 1184        AC   6000   20     NO
# 1185    NON AC   3000   30    YES
# 1186        AC   4000   30    YES
# 1187        AC   5000   20    YES
# 1188        AC   6000   30     NO
# 1189        AC   2000   20    YES
# 1190        AC   4000   20     NO
# 1191        AC   4000   30    YES
# 1192        AC   3000   40     NO
# 1193        AC   3000   30    YES
# 1194        AC   5000   30     NO
# 1195    NON AC   4000   20    YES
# 1196        AC   3000   30     NO
# 1197        AC   4000   20    YES
# 1198        AC   3000   20     NO
# 1199        AC   4000   20    YES
# 1200        AC   4000   30     NO
# 1201        AC   3000   40    YES
# 1202    NON AC   1000   20    YES
# 1203        AC   3000   30     NO
# 1204        AC   4000   50    YES
# 1205       YES   2000   20     NO
# 1206        NO   2000   20     NO
# 1207       YES   4000   20    YES
# 1208        AC   2000   20    YES
# 1209        AC   3000   20     NO
# 1210        AC   4000   30    YES
# 1211        AC   4000   20     NO
#
# [1212 rows x 11 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-42-f99602520847> in <module>()
#       2 print(df)
#       3 df=df.drop(['CustomerID'],1)
# ----> 4 df=handle_non_numerical_data(df)
#       5 print(df)
#       6 Booked=df['Booked']
#
# <ipython-input-38-c372eb8868c8> in handle_non_numerical_data(df)
#      15                     #print(unique,x)
#      16                     x+=1
# ---> 17             df[column]=list(map(convert_to_int,df[columns]))
#      18     return df
#
# <ipython-input-38-c372eb8868c8> in convert_to_int(val)
#       5         text_digit_vals={}
#       6         def convert_to_int(val):
# ----> 7             return text_digit_vals[val]
#       8         if df[column].dtype!=np.int64 and df[column].dtype!=np.float64:
#       9             column_contents=df[column].values.tolist()
#
# KeyError: 'DaysBooking'

# %%
Data=df['Age']
Out=df['Booked']
Yes=[]
No=[]
temp=[]
temp1=[]
for i in range(len(Out)):
    if(Out[i]==0):
        Yes.append(Data[i])
        temp.append(Out[i])
    else:
        No.append(Data[i])
        temp1.append(Out[i])
print(len(Yes))
print(len(temp))
plt.title("Green=Yes  Red=No")
plt.ylabel("Age")
plt.xlabel('Booked (0=Yes 1=No)')
plt.plot(temp,Yes,color='green')
plt.plot(temp1,No,color='red')
plt.show()
# Out:
# 0
# 0
